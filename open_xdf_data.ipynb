# %%
import pyxdf
import

# Load an XDF file
streams, fileheader = pyxdf.load_xdf('../../CurrentStudy/sub-P001/ses-S001/eeg/sub-P001_ses-S001_task-Default_run-001_eeg.xdf')
# Out:
#   Cell In[2], line 2
#     import
#           ^
# SyntaxError: invalid syntax

# %%
import pyxdf
import matplotlib.pyplot as plt

# %%
# Load an XDF file
streams, fileheader = pyxdf.load_xdf('../../CurrentStudy/sub-P001/ses-S001/eeg/sub-P001_ses-S001_task-Default_run-001_eeg.xdf')

# %%
print(streams[0]['time_series'].shape)
# Out:
# (8077, 2)

# %%
print(streams[2]['time_series'].shape)
plt.plot(streams[2]['time_series'])
# Out:
# (20271, 37)
# ...

# %%
print(streams[0]['time_series'].shape)
plt.plot(streams[0]['time_series'])
# Out:
# (8077, 2)
# ...

# %%
plt.figure()
plt.plot(streams[0]['time_series'])
