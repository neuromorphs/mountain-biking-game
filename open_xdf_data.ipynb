# %%
import csv
STEERING_CSV_FILE_NAME = './results/QinyuChen/QinyuChen_trial_1.csv'
steering_csv_file = open(STEERING_CSV_FILE_NAME, 'r')
steering_reader = csv.DictReader(filter(lambda row: row[0] != '#', steering_csv_file))

# Count of many rows in the csv file
count = 0
for row in steering_reader:
    count += 1
print(count)
# Out:
# 8775

# %%
import numpy as np
import matplotlib.pyplot as plt
steering_predicted = np.load('0_steering_predicted.npy')
len(steering_predicted)

# Plot the steering predicted values
plt.figure(figsize=(10, 5))
plt.plot(steering_predicted)
plt.title('Steering Predicted Values')
plt.xlabel('Frame')
plt.ylabel('Steering Value')
plt.show()

# Plot the steering value



# Save the steering predicted values to a csv file with header steering11
import csv
STEERING_CSV_FILE_NAME = './results/QinyuChen/QinyuChen_trial_1.csv'
steering_csv_file = open(STEERING_CSV_FILE_NAME, 'r')
steering_reader = csv.DictReader(filter(lambda row: row[0] != '#', steering_csv_file))
# Out:
# 8765

# %%
100
1/100 = 0.01
# Out:
# 8765

# %%
plt.figure()
plt.plot(streams[0]['time_series'])
